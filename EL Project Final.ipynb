# %%
import pandas as pd
data = pd.read_csv("J:\CFiles\pyprojects\EL_project\dataset.csv")
dep=input(print("Enter source airport"))
arr=input(print("Enter destination airport"))
ac=input(print("Enter any specefic flight"))
t1=0
t2=0
t1=input(print("Enter Early time"))
t2=input(print("Enter Late time"))
data[['LOCAL_AIRPORT', 'SOURCE_DESTINATION','SCHED_TIME']]
data[(data.LOCAL_AIRPORT == dep) & (data.SOURCE_DESTINATION == arr)]
# Out:
# Enter source airport
# NoneJAI
# Enter destination airport
# NoneDEL
# Enter any specefic flight
# None9W
# Enter Early time
# None1200
# Enter Late time
# None2300
#       LOCAL_AIRPORT AIRLINE_CODE  FLIGHT_NUMBER  FREQUENCY  \
# 11674           JAI           9W           2169    1234567
# 11675           JAI           9W           2169    1234567
# 11676           JAI           SG           2623    1234567
# 11677           JAI           9W           2249    1234567
# 11678           JAI           9W           2249    1234567
# 11679           JAI           9W           2249    1234567
# 11680           JAI           9W           2249    1234567
# 11681           JAI           SG           2623    1234567
# 11682           JAI           SG           2623    1234567
# 11683           JAI           6E           5098    1234567
# 11684           JAI           6E           5098    1234567
# 11685           JAI           9W           2459    1234567
# ...
